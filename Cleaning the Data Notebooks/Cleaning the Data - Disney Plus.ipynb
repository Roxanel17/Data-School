# %% [markdown]
# ## CLEANING THE DATA FOR DISNEY PLUS DATASET

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load data

# %% [markdown]
# Tip: Change encoding from 'latin-1' to 'utf-8' to get rid of special characters that may appear in the dataset.

# %%
df = pd.read_csv("../date raw/DataSchool_DisneyPlus.csv", encoding = 'utf-8')
df.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos| Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos| Tony Anselmo| Tress MacN...            NaN
# 1           Jim Varney| Noelle Parker| Douglas Seale            NaN
# 2  Raymond Albert Romano| John Leguizamo| Denis L...  United States
# 3  Darren Criss| Adam Lambert| Derek Hough| Alexa...            NaN
# 4  John Lennon| Paul McCartney| George Harrison| ...            NaN
#
#   date_added  release_year rating  duration                      listed_in  \
# 0  26-Nov-21          2016   TV-G    23 min              Animation| Family
# 1  26-Nov-21          1988     PG    91 min                         Comedy
# 2  26-Nov-21          2011   TV-G    23 min      Animation| Comedy| Family
# 3  26-Nov-21          2021  TV-PG    41 min                        Musical
# 4  25-Nov-21          2021    NaN  1 Season  Docuseries| Historical| Music
#
#                                          description
# 0   Join Mickey and the gang as they duck the halls!
# 1  Santa Claus passes his magic bag to a new St. ...
# 2          Sid the Sloth is on Santa's naughty list.
# 3               This is real life; not just fantasy!
# 4  A three-part documentary from Peter Jackson ca...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1450 non-null   object
#  1   type          1450 non-null   object
#  2   title         1450 non-null   object
#  3   director      977 non-null    object
#  4   cast          1260 non-null   object
#  5   country       1231 non-null   object
#  6   date_added    1447 non-null   object
#  7   release_year  1450 non-null   int64
#  8   rating        1447 non-null   object
#  9   duration      1450 non-null   object
#  10  listed_in     1450 non-null   object
#  11  description   1450 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 136.1+ KB

# %% [markdown]
# Step 1: Find the percentage of missing data in order to make decisions in order to drop or input the values

# %% [markdown]
# Percentage of missing data for each feature
# - For 'director' -> 32.62%
# - For 'cast' -> 13.10%
# - For 'country' -> 15.10
# - For 'date_added' & 'rating'-> 0.21%, we have only 3 missing values

# %%
df["director"].isnull().sum()/len(df["director"])*100
# Out:
# 32.62068965517241

# %%
df["cast"].isnull().sum()/len(df["cast"])*100
# Out:
# 13.10344827586207

# %%
df["country"].isnull().sum()/len(df["country"])*100
# Out:
# 15.10344827586207

# %%
df["date_added"].isnull().sum()/len(df["date_added"])*100
df["rating"].isnull().sum()/len(df["rating"])*100
# Out:
# 0.20689655172413793

# %% [markdown]
# Step 2: Remove duplicates based on all columns

# %%
df.drop_duplicates(inplace=True)
df.drop_duplicates(subset='title', inplace=True)

# %%
df.dropna(subset = ['date_added'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1447 entries, 0 to 1449
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1447 non-null   object
#  1   type          1447 non-null   object
#  2   title         1447 non-null   object
#  3   director      977 non-null    object
#  4   cast          1257 non-null   object
#  5   country       1228 non-null   object
#  6   date_added    1447 non-null   object
#  7   release_year  1447 non-null   int64
#  8   rating        1444 non-null   object
#  9   duration      1447 non-null   object
#  10  listed_in     1447 non-null   object
#  11  description   1447 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 147.0+ KB

# %%
df.loc[4, 'rating'] = 'PG-13'
df.loc[276, 'rating'] = 'TV-14'
df.loc[280, 'rating'] = 'TV-14'
df.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos| Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos| Tony Anselmo| Tress MacN...            NaN
# 1           Jim Varney| Noelle Parker| Douglas Seale            NaN
# 2  Raymond Albert Romano| John Leguizamo| Denis L...  United States
# 3  Darren Criss| Adam Lambert| Derek Hough| Alexa...            NaN
# 4  John Lennon| Paul McCartney| George Harrison| ...            NaN
#
#   date_added  release_year rating  duration                      listed_in  \
# 0  26-Nov-21          2016   TV-G    23 min              Animation| Family
# 1  26-Nov-21          1988     PG    91 min                         Comedy
# 2  26-Nov-21          2011   TV-G    23 min      Animation| Comedy| Family
# 3  26-Nov-21          2021  TV-PG    41 min                        Musical
# 4  25-Nov-21          2021  PG-13  1 Season  Docuseries| Historical| Music
#
#                                          description
# 0   Join Mickey and the gang as they duck the halls!
# 1  Santa Claus passes his magic bag to a new St. ...
# 2          Sid the Sloth is on Santa's naughty list.
# 3               This is real life; not just fantasy!
# 4  A three-part documentary from Peter Jackson ca...

# %% [markdown]
# Step 3: Format data as YYYY-MM-DD (e.g. 2021-09-25)

# %%
df['date_added'].head(2)
# Out:
# 0    26-Nov-21
# 1    26-Nov-21
# Name: date_added, dtype: object

# %%
df["date_added"] = pd.to_datetime(df["date_added"]).dt.date
df["date_added"].head()
# Out:
# 0    2021-11-26
# 1    2021-11-26
# 2    2021-11-26
# 3    2021-11-26
# 4    2021-11-25
# Name: date_added, dtype: object

# %%
df.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos| Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos| Tony Anselmo| Tress MacN...            NaN
# 1           Jim Varney| Noelle Parker| Douglas Seale            NaN
# 2  Raymond Albert Romano| John Leguizamo| Denis L...  United States
# 3  Darren Criss| Adam Lambert| Derek Hough| Alexa...            NaN
# 4  John Lennon| Paul McCartney| George Harrison| ...            NaN
#
#    date_added  release_year rating  duration                      listed_in  \
# 0  2021-11-26          2016   TV-G    23 min              Animation| Family
# 1  2021-11-26          1988     PG    91 min                         Comedy
# 2  2021-11-26          2011   TV-G    23 min      Animation| Comedy| Family
# 3  2021-11-26          2021  TV-PG    41 min                        Musical
# 4  2021-11-25          2021  PG-13  1 Season  Docuseries| Historical| Music
#
#                                          description
# 0   Join Mickey and the gang as they duck the halls!
# 1  Santa Claus passes his magic bag to a new St. ...
# 2          Sid the Sloth is on Santa's naughty list.
# 3               This is real life; not just fantasy!
# 4  A three-part documentary from Peter Jackson ca...

# %% [markdown]
# Step 4: Fix the problems with rating column

# %%
df['rating'].head(7)
# Out:
# 0     TV-G
# 1       PG
# 2     TV-G
# 3    TV-PG
# 4    PG-13
# 5    PG-13
# 6    TV-14
# Name: rating, dtype: object

# %%
# Replace np.NaN with Not Rated
df['rating'].replace(np.NaN, 'Not Rated', inplace=True)

# %% [markdown]
# Step 5: Split duration column into duration as a number and unit_of_measure (min for movies and season for tv shows)

# %%
# split column and add new columns to df
df[['duration_show', 'unit_measure']] = df['duration'].str.split(' ', expand=True)
# display the dataframe
df.head(2)
# Out:
#   show_id   type                                             title  \
# 0      s1  Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2  Movie                            Ernest Saves Christmas
#
#                             director  \
# 0  Alonso Ramirez Ramos| Dave Wasson
# 1                        John Cherry
#
#                                                 cast country  date_added  \
# 0  Chris Diamantopoulos| Tony Anselmo| Tress MacN...     NaN  2021-11-26
# 1           Jim Varney| Noelle Parker| Douglas Seale     NaN  2021-11-26
#
#    release_year rating duration          listed_in  \
# 0          2016   TV-G   23 min  Animation| Family
# 1          1988     PG   91 min             Comedy
#
#                                          description duration_show  \
# 0   Join Mickey and the gang as they duck the halls!            23
# 1  Santa Claus passes his magic bag to a new St. ...            91
#
#   unit_measure
# 0          min
# 1          min

# %%
df.drop(['duration'], axis=1, inplace=True)

# %%
df.head(2)
# Out:
#   show_id   type                                             title  \
# 0      s1  Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2  Movie                            Ernest Saves Christmas
#
#                             director  \
# 0  Alonso Ramirez Ramos| Dave Wasson
# 1                        John Cherry
#
#                                                 cast country  date_added  \
# 0  Chris Diamantopoulos| Tony Anselmo| Tress MacN...     NaN  2021-11-26
# 1           Jim Varney| Noelle Parker| Douglas Seale     NaN  2021-11-26
#
#    release_year rating          listed_in  \
# 0          2016   TV-G  Animation| Family
# 1          1988     PG             Comedy
#
#                                          description duration_show  \
# 0   Join Mickey and the gang as they duck the halls!            23
# 1  Santa Claus passes his magic bag to a new St. ...            91
#
#   unit_measure
# 0          min
# 1          min

# %% [markdown]
# Step 6: replace Seasons with Season

# %%
df['unit_measure'].replace('Seasons', 'Season', inplace=True)
df.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos| Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos| Tony Anselmo| Tress MacN...            NaN
# 1           Jim Varney| Noelle Parker| Douglas Seale            NaN
# 2  Raymond Albert Romano| John Leguizamo| Denis L...  United States
# 3  Darren Criss| Adam Lambert| Derek Hough| Alexa...            NaN
# 4  John Lennon| Paul McCartney| George Harrison| ...            NaN
#
#    date_added  release_year rating                      listed_in  \
# 0  2021-11-26          2016   TV-G              Animation| Family
# 1  2021-11-26          1988     PG                         Comedy
# 2  2021-11-26          2011   TV-G      Animation| Comedy| Family
# 3  2021-11-26          2021  TV-PG                        Musical
# 4  2021-11-25          2021  PG-13  Docuseries| Historical| Music
#
#                                          description duration_show  \
# 0   Join Mickey and the gang as they duck the halls!            23
# 1  Santa Claus passes his magic bag to a new St. ...            91
# 2          Sid the Sloth is on Santa's naughty list.            23
# 3               This is real life; not just fantasy!            41
# 4  A three-part documentary from Peter Jackson ca...             1
#
#   unit_measure
# 0          min
# 1          min
# 2          min
# 3          min
# 4       Season

# %% [markdown]
# Step 7: format duration_show as a whole number (int)

# %%
df['duration_show'] = df['duration_show'].astype('int')
df['duration_show'].groupby(df['type']).describe()
# Out:
#           count       mean        std  min   25%   50%   75%    max
# type
# Movie    1052.0  71.910646  40.595585  1.0  44.0  85.0  98.0  183.0
# TV Show   395.0   2.113924   2.420237  1.0   1.0   1.0   2.0   32.0

# %% [markdown]
# Step 8: fix the problem with 'duration' for the following TV Shows:
# - Obi-Wan Kenobi;
# - Baymax!;
# - The Proud Family: Louder and Prouder.
# The issue is that they have a duration listed if 1 min, instead of 1 season according to what Google says :)

# %%
df.loc[df['title']=='Obi-Wan Kenobi']
df.loc[df['title']=='Baymax!']
df.loc[df['title']=='The Proud Family: Louder and Prouder']
# Out:
#    show_id   type                                 title director  \
# 37     s38  Movie  The Proud Family: Louder and Prouder      NaN
#
#                                                  cast country  date_added  \
# 37  Kyla Pratt| Tommy Davidson| Paula Jai Parker| ...     NaN  2021-11-12
#
#     release_year rating                         listed_in  \
# 37          2021   TV-G  Animation| Comedy| Coming of Age
#
#                                           description  duration_show  \
# 37  "The Proud Family: Louder and Prouder" follows...              1
#
#    unit_measure
# 37          min

# %%
df.loc[27, 'unit_measure']='Season'
df.loc[27, 'type']='TV Show'
df.loc[15, 'unit_measure']='Season'
df.loc[15, 'type']='TV Show'
df.loc[37, 'unit_measure']='Season'
df.loc[37, 'type']='TV Show'

# %% [markdown]
# Step 9: Deal with outliers

# %%
df.loc[(df['duration_show'] >6) & (df['type']=='TV Show')]
# Out:
#     show_id     type                           title director  \
# 13      s14  TV Show           Dr. Oakley| Yukon Vet      NaN
# 92      s93  TV Show                    The Simpsons      NaN
# 106    s107  TV Show                 Life Below Zero      NaN
# 115    s116  TV Show          The Incredible Dr. Pol      NaN
# 125    s126  TV Show        Dr. K's Exotic Animal ER      NaN
# 179    s180  TV Show              When Sharks Attack      NaN
# 216    s217  TV Show                     Wicked Tuna      NaN
# 285    s286  TV Show                         Car SOS      NaN
# 307    s308  TV Show        Wicked Tuna: Outer Banks      NaN
# 412    s413  TV Show                Once Upon a Time      NaN
# 553    s554  TV Show  America's Funniest Home Videos      NaN
# 557    s558  TV Show                     Brain Games      NaN
# 618    s619  TV Show       Star Wars: The Clone Wars      NaN
# 759    s760  TV Show                 Boy Meets World      NaN
#
#                                                   cast         country  \
# 13                   Dr. Michelle Oakley| Zachary Fine   United States
# 92   Dan Castellaneta| Julie Kavner| Nancy Cartwrig...   United States
# 106  Chip Hailstone| Agnes Hailstone| Sue Aikens| A...   United States
# 115                               Rick Robles| Dr. Pol   United States
# 125                    Dr. Susan Kelleher| Art Edmonds             NaN
# 179                                        Eric Meyers   United States
# 216                                          Mike Rowe   United States
# 285                                                NaN  United Kingdom
# 307                                        Bill Ratner             NaN
# 412  Ginnifer Goodwin| Jennifer Morrison| Robert Ca...   United States
# 553                                       Tom Bergeron   United States
# 557                                        Neil Harris   United States
# 618  Tom Kane| Matt Lanter| Ashley Eckstein| James ...   United States
# 759  Ben Savage| William Daniels| Betsy Randle| Wil...   United States
#
#      date_added  release_year rating  \
# 13   2021-11-17          2013  TV-PG
# 92   2021-09-29          1989  TV-PG
# 106  2021-09-15          2012  TV-14
# 115  2021-09-08          2011  TV-14
# 125  2021-08-25          2014  TV-14
# 179  2021-07-09          2013  TV-14
# 216  2021-05-28          2016  TV-14
# 285  2021-02-26          2012  TV-PG
# 307  2021-02-05          2013  TV-14
# 412  2020-09-18          2011  TV-PG
# 553  2020-04-24          1989  TV-PG
# 557  2020-04-17          2011   TV-G
# 618  2020-02-21          2008  TV-PG
# 759  2019-11-12          1993  TV-PG
#
#                                              listed_in  \
# 13      Action-Adventure| Animals & Nature| Docuseries
# 92                                   Animation| Comedy
# 106     Action-Adventure| Animals & Nature| Docuseries
# 115               Animals & Nature| Docuseries| Family
# 125               Animals & Nature| Docuseries| Family
# 179                                            Reality
# 216     Action-Adventure| Animals & Nature| Docuseries
# 285                          Buddy| Comedy| Docuseries
# 307               Animals & Nature| Docuseries| Family
# 412  Action-Adventure| Fantasy| Soap Opera / Melodrama
# 553                            Comedy| Family| Fantasy
# 557        Docuseries| Family| Game Show / Competition
# 618       Action-Adventure| Animation| Science Fiction
# 759                      Comedy| Coming of Age| Family
#
#                                            description  duration_show  \
# 13   Meet Dr. Michelle Oakley; vet to pretty much e...             10
# 92   The world’s favorite nuclear family; in the aw...             32
# 106  Experience life deep in Alaska where the prima...             16
# 115  Dr. Pol and his team handle challenging veteri...             19
# 125  Dedicated veterinarians treat a colorful array...              9
# 179    National Geographic investigates shark attacks.              7
# 216  Massachusetts fishermen make their living one ...             10
# 285  Decaying classic cars are revived by two exper...              8
# 307  Fishermen venture to North Carolina’s Outer Ba...              7
# 412  Fairy tale characters inhabit a land of good a...              7
# 553  Home videos compete for cash prizes. Program i...              9
# 557  Brain Games features games & experiments revea...              8
# 618       The saga continues; set in a faraway galaxy!              7
# 759  Adolescent Cory Matthews grows up; and faces p...              7
#
#     unit_measure
# 13        Season
# 92        Season
# 106       Season
# 115       Season
# 125       Season
# 179       Season
# 216       Season
# 285       Season
# 307       Season
# 412       Season
# 553       Season
# 557       Season
# 618       Season
# 759       Season

# %% [markdown]
# Step 10: Make sure that title is a string (some movies have dates as title) and release_year is a integer

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1447 entries, 0 to 1449
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   show_id        1447 non-null   object
#  1   type           1447 non-null   object
#  2   title          1447 non-null   object
#  3   director       977 non-null    object
#  4   cast           1257 non-null   object
#  5   country        1228 non-null   object
#  6   date_added     1447 non-null   object
#  7   release_year   1447 non-null   int64
#  8   rating         1447 non-null   object
#  9   listed_in      1447 non-null   object
#  10  description    1447 non-null   object
#  11  duration_show  1447 non-null   int64
#  12  unit_measure   1447 non-null   object
# dtypes: int64(2), object(11)
# memory usage: 190.6+ KB

# %%
df['title'].describe()
# Out:
# count                                                 1447
# unique                                                1447
# top       Duck the Halls: A Mickey Mouse Christmas Special
# freq                                                     1
# Name: title, dtype: object

# %%
df['release_year'].astype('int')
# Out:
# 0       2016
# 1       1988
# 2       2011
# 3       2021
# 4       2021
#         ...
# 1445    2009
# 1446    2009
# 1447    2016
# 1448    2003
# 1449    2012
# Name: release_year, Length: 1447, dtype: int64

# %% [markdown]
# Step 11: fill empty cells for director, cast, country and date_added with NaN

# %%
df['director'].fillna(np.NaN, inplace=True)
df['cast'].fillna(np.NaN, inplace=True)
df['country'].fillna(np.NaN, inplace=True)

# %% [markdown]
# Step 12: Save all changes into a new csv labeled "DataSchool_DisneyPlus_Clean.csv"

# %%
df.to_csv('DataSchool_DisneyPlus_Clean.csv')

# %%
df.to_excel('DataSchool_DisneyPlus_Clean.xlsx', encoding='utf-8')
